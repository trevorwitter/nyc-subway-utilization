# %%
import pandas as pd
from utils import extract_mta_data

# %%
df1 = extract_mta_data('221008')
# Out:
# /Users/twitter/Desktop/Current Research/nyc_subway/v2/utils.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_)

# %%
df1.head()
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 33107  H007  R248  00-00-00    1 AV        L      BMT  10/01/2022
# 33108  H007  R248  00-00-00    1 AV        L      BMT  10/01/2022
# 33109  H007  R248  00-00-00    1 AV        L      BMT  10/01/2022
# 33110  H007  R248  00-00-00    1 AV        L      BMT  10/01/2022
# 33111  H007  R248  00-00-00    1 AV        L      BMT  10/01/2022
#
#                      TIME     DESC   ENTRIES     EXITS
# 33107 2022-10-01 00:00:00  REGULAR  15845079  19027035
# 33108 2022-10-01 04:00:00  REGULAR  15845098  19027234
# 33109 2022-10-01 08:00:00  REGULAR  15845108  19027401
# 33110 2022-10-01 12:00:00  REGULAR  15845163  19027781
# 33111 2022-10-01 16:00:00  REGULAR  15845254  19028361

# %%
df1[df1['TIME'].dt.minute!=0]
# Out:
#         C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 33128  H007  R248  00-00-00             1 AV        L      BMT  10/04/2022
# 33171  H007  R248  00-00-01             1 AV        L      BMT  10/04/2022
# 33214  H007  R248  00-03-00             1 AV        L      BMT  10/04/2022
# 33257  H007  R248  00-03-01             1 AV        L      BMT  10/04/2022
# 33300  H007  R248  00-03-02             1 AV        L      BMT  10/04/2022
# ...     ...   ...       ...              ...      ...      ...         ...
# 63292  N094  R029  01-06-01  WORLD TRADE CTR    ACE23      IND  10/01/2022
# 63335  N094  R029  01-06-02  WORLD TRADE CTR    ACE23      IND  10/01/2022
# 63336  N094  R029  01-06-02  WORLD TRADE CTR    ACE23      IND  10/01/2022
# 63379  N094  R029  01-06-03  WORLD TRADE CTR    ACE23      IND  10/01/2022
# 63380  N094  R029  01-06-03  WORLD TRADE CTR    ACE23      IND  10/01/2022
#
#                      TIME     DESC   ENTRIES     EXITS
# ...

# %%
df1[df1['TIME'].dt.minute==0]
# Out:
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 33107   H007  R248  00-00-00       1 AV        L      BMT  10/01/2022
# 33108   H007  R248  00-00-00       1 AV        L      BMT  10/01/2022
# 33109   H007  R248  00-00-00       1 AV        L      BMT  10/01/2022
# 33110   H007  R248  00-00-00       1 AV        L      BMT  10/01/2022
# 33111   H007  R248  00-00-00       1 AV        L      BMT  10/01/2022
# ...      ...   ...       ...        ...      ...      ...         ...
# 185405  R419  R326  00-05-01  ZEREGA AV        6      IRT  10/07/2022
# 185406  R419  R326  00-05-01  ZEREGA AV        6      IRT  10/07/2022
# 185407  R419  R326  00-05-01  ZEREGA AV        6      IRT  10/07/2022
# 185408  R419  R326  00-05-01  ZEREGA AV        6      IRT  10/07/2022
# 185409  R419  R326  00-05-01  ZEREGA AV        6      IRT  10/07/2022
#
#                       TIME     DESC   ENTRIES     EXITS
# 33107  2022-10-01 00:00:00  REGULAR  15845079  19027035
# ...

# %%
df = df1[df1['STATION'] =='103 ST'].copy()

# %%
df = df1[df1['STATION'] =='103 ST'].copy()
dfg = df[['TIME','ENTRIES','EXITS']].groupby(['TIME']).sum()
dfg.plot()
# Out:
# <AxesSubplot:xlabel='TIME'>

# %%
df = df1[df1['STATION'] =='7 AV'].copy()
dfg = df[['TIME','ENTRIES','EXITS']].groupby(['TIME']).sum()
dfg.plot()

# %%
dfg
# Out:
#                        ENTRIES      EXITS
# TIME
# 2022-10-01 01:00:00  140137224  125877272
# 2022-10-01 05:00:00  140137287  125877766
# 2022-10-01 09:00:00  140138182  125878856
# 2022-10-01 13:00:00  140140079  125880834
# 2022-10-01 17:00:00  140142198  125883711
# 2022-10-01 21:00:00  140143921  125886540
# 2022-10-02 01:00:00  140144587  125888441
# 2022-10-02 05:00:00  140144658  125888925
# 2022-10-02 09:00:00  140145377  125889606
# 2022-10-02 13:00:00  140147086  125891283
# 2022-10-02 17:00:00  140148903  125893978
# 2022-10-02 21:00:00  140150107  125896604
# 2022-10-03 01:00:00  140150577  125898116
# 2022-10-03 05:00:00  140150665  125898318
# 2022-10-03 09:00:00  140153998  125902323
# 2022-10-03 13:00:00  140156684  125905307
# 2022-10-03 17:00:00  140160764  125909794
# 2022-10-03 21:00:00  140163575  125914719
# 2022-10-04 01:00:00  140164080  125916498
# 2022-10-04 05:00:00  140164174  125916710
# 2022-10-04 09:00:00  140167597  125920535
# ...

# %%
dfg[dfg.index.minute==0].diff().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='TIME'>
